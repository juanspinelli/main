# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
sns.set(style="whitegrid")
# %matplotlib inline

# %%
datos = pd.read_csv('Datos/google-play-store-apps/googleplaystore.csv', sep=',')

# %%
datos.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df = pd.DataFrame(datos)

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# 5                             Paper flowers instructions       ART_AND_DESIGN
# 6                Smoke Effect Photo Maker - Smoke Editor       ART_AND_DESIGN
# 7                                       Infinite Painter       ART_AND_DESIGN
# 8                                   Garden Coloring Book       ART_AND_DESIGN
# 9                          Kids Paint Free - Drawing Fun       ART_AND_DESIGN
# 10                               Text on Photo - Fonteee       ART_AND_DESIGN
# ...

# %%
df.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
df.shape
# Out:
# (10841, 13)

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
df.rename(columns={'Category' : 'Categoria', 'Rating' : 'Puntaje', 
                   'Size' : 'Peso', 'Installs' : 'Instalaciones', 
                   'Type': 'Tipo', 'Price' : 'Precio', 'Content Rating' : 'Contenido_apto',
                   'Genres' : 'Genero', 'Last Updated' : 'Ultima_actualizacion', 
                   'Current Ver' : 'Version_actual', 'Android Ver' : 'Version_de_Android'}, inplace=True)

# %%
df.columns
# Out:
# Index(['App', 'Categoria', 'Puntaje', 'Reviews', 'Peso', 'Instalaciones',
#        'Tipo', 'Precio', 'Contenido_apto', 'Genero', 'Ultima_actualizacion',
#        'Version_actual', 'Version_de_Android'],
#       dtype='object')

# %%
df.head(3)
# Out:
#                                                  App       Categoria  Puntaje  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN      4.1
# 1                                Coloring book moana  ART_AND_DESIGN      3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN      4.7
#
#   Reviews  Peso Instalaciones  Tipo Precio Contenido_apto  \
# 0     159   19M       10,000+  Free      0       Everyone
# 1     967   14M      500,000+  Free      0       Everyone
# 2   87510  8.7M    5,000,000+  Free      0       Everyone
#
#                       Genero Ultima_actualizacion Version_actual  \
# 0               Art & Design      January 7, 2018          1.0.0
# 1  Art & Design;Pretend Play     January 15, 2018          2.0.0
# 2               Art & Design       August 1, 2018          1.2.4
#
#   Version_de_Android
# 0       4.0.3 and up
# 1       4.0.3 and up
# 2       4.0.3 and up

# %%
df.isnull().any().any()
# Out:
# True

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
# App                     10841 non-null object
# Categoria               10841 non-null object
# Puntaje                 9367 non-null float64
# Reviews                 10841 non-null object
# Peso                    10841 non-null object
# Instalaciones           10841 non-null object
# Tipo                    10840 non-null object
# Precio                  10841 non-null object
# Contenido_apto          10840 non-null object
# Genero                  10841 non-null object
# Ultima_actualizacion    10841 non-null object
# Version_actual          10833 non-null object
# Version_de_Android      10838 non-null object
# dtypes: float64(1), object(12)
# memory usage: 592.9+ KB

# %%
df.count()
# Out:
# App                     10841
# Categoria               10841
# Puntaje                  9367
# Reviews                 10841
# Peso                    10841
# Instalaciones           10841
# Tipo                    10840
# Precio                  10841
# Contenido_apto          10840
# Genero                  10841
# Ultima_actualizacion    10841
# Version_actual          10833
# Version_de_Android      10838
# dtype: int64

# %%
df.dtypes
# Out:
# App                      object
# Categoria                object
# Puntaje                 float64
# Reviews                  object
# Peso                     object
# Instalaciones            object
# Tipo                     object
# Precio                   object
# Contenido_apto           object
# Genero                   object
# Ultima_actualizacion     object
# Version_actual           object
# Version_de_Android       object
# dtype: object

# %%
def generalCountPlot(x=None, data=None, pattel='autumn'):
    plt.figure(figsize=(12,7))
    plt.xticks(rotation=90)
    sns.countplot(x=x, data=data, palette=pattel)

# %%
generalCountPlot('Categoria', df)

# %%
generalCountPlot('Instalaciones', df)

# %%
generalCountPlot('Version_de_Android', df, 'rainbow')

# %%
generalCountPlot('Tipo', df, 'summer')

# %%
plt.figure(figsize=(10,7))
plt.xticks(rotation=90)
temp_value = df.Version_de_Android.value_counts().sort_values(ascending=True)[-20:]
sns.pointplot(x=temp_value.index, y=temp_value.values, hue=temp_value.index, estimator=np.sum, orient="v")

# %%
df.dtypes
# Out:
# App                      object
# Categoria                object
# Puntaje                 float64
# Reviews                  object
# Peso                     object
# Instalaciones            object
# Tipo                     object
# Precio                   object
# Contenido_apto           object
# Genero                   object
# Ultima_actualizacion     object
# Version_actual           object
# Version_de_Android       object
# dtype: object

# %%
generalCountPlot('Tipo',df[df.Categoria == 'ART_AND_DESIGN'],"Wistia" )

# %%
generalCountPlot('Tipo',df[df.Categoria == 'BOOKS_AND_REFERENCE'],"Wistia" )
